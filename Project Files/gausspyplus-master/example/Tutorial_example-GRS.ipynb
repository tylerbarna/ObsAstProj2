# %% [markdown]
# # GaussPy+ tutorial for a test field of the Galactic Ring Survey
#
# This notebook is intended to guide users through the typical GaussPy+ procedures for the decomposition of a position-position-velocity (PPV) dataset.
#
# For more information exceeding this tutorial we recommend taking a look at the following papers and documents:
#
# - For a description about the GaussPy+ decomposition package see:
# > - Riener+ 2019 (subm.): GaussPy+: A fully automated Gaussian decomposition package for emission line spectra
#
# - For a description about the GaussPy algorithm see:
# > - [GaussPy documentation](https://gausspy.readthedocs.io/en/latest/)
# > - [Lindner et al. 2015](https://arxiv.org/abs/1409.2840)

# %%
import os

from astropy.io import fits

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from pylab import cm

from astropy.wcs import WCS

from gausspyplus.plotting import get_points_for_colormap, shiftedColorMap


def get_cmap_rchi2(vmin, vmax):
    orig_cmap = matplotlib.cm.RdBu_r
    start, stop = get_points_for_colormap(vmin, vmax, central_val=1.)
    midpoint = (1 - vmin) / (vmax - vmin)
    return shiftedColorMap(orig_cmap, start=0., midpoint=midpoint, stop=stop)


def add_style(ax):
    ax.set_xlabel('Galactic Longitude')
    ax.set_ylabel('Galactic Latitude')
    ax.invert_yaxis()


if not os.path.exists('decomposition_grs'):
    # !mkdir decomposition_grs

# %% [markdown]
# ## Overview
#
# This tutorial consists of the following steps:
#
# - Step 0: Create a configuration file (optional)
#
# - Step 1: Create a training set from the data
#
# - Step 2: Find the optimal values for the smoothing parameters $\alpha_{1}$ and $\alpha_{2}$
#
# - Step 3: Prepare the data for the decomposition
#
# - Step 4: Decomposition of the data
#
# - Step 5: Spatially coherent refitting - phase 1
#
# - Step 6: Spatially coherent refitting - phase 2
#
# This directory contains the FITS cube `grs-test_field.fits`, which is a subset of the Galactic Ring Survey (Jackson+ 2006) that we will use for this tutorial. This is the same dataset that was used as a test field in Riener+ 2019.

# %% [markdown]
# ## Step 0: Create a configuration file (optional)
#
# We start by generating a default configuration file. The next code creates a configuration file called 'gausspy+.ini' in the current working directory.

# %%
import gausspyplus.config_file as cf
cf.make()
# Out:
# SAVED FILE: 'gausspy+.ini' in 'C:\Users\Tyler\Google Drive (barnanator@gmail.com)\College\2019-2020 Junior\343 Observational Astronomy\Project 2\Project Files\gausspyplus-master\example'

# %% [markdown]
# This configuration file only contains the most essential parameters, which in many cases should already be sufficient to create first good results.
#
# To take a look or access the full range of keywords that can be changed by the user change the above command to `cf.make(all_keywords=True)`.
#
# It is not necessary to create a configuration file for running `GaussPy+`. If no configuration file is supplied `GaussPy+` will resort to the default value for the parameters.
#
# Parameters can also be supplied or changed later on as will be done in the scripts further below.

# %% [markdown]
# ## Step 1: Create a training set from the data
#
# Now we create a training set from the FITS cube `grs-test_field.fits`. For this we execute the `training_set--grs.py` script contained in the `example` directory. See the `training_set--grs.py` script for more comments.
#
# **NOTE: Running this script will use 75% of all CPUs on the machine you are running it unless the** `use_ncpus` **parameter is specified.**
#
# Depending on the number of available CPUs the execution of this script might take a couple of minutes.

# %%
#  run the script
# !python training_set--grs.py
# Out:
# ^C

# %% [markdown]
# ### Results
# After this script was successfully executed, the `decomposition_grs` directory should contain a folder named `gpy_training` with two files:
#
# - `grs-test_field-training_set_100_spectra.pickle`: a pickled dictionary of the decomposition results of the training set
#
# - `grs-test_field-training_set_100_spectra_plots.pdf`: plots of the decomposition results. We recommend to always plot a subsample of the training set to check whether the fitting of the training set worked out well.
#
# Since this example serves only to illustrate how training sets can be created we kept the number of spectra of the training set deliberately low. We recommend to include at least 200 spectra in the training set to get good results for the smoothing parameters.

# %% [markdown]
# ## Step 2: Find the optimal values for the smoothing parameters $\alpha_{1}$ and $\alpha_{2}$
#
# After we checked that the decomposition of the training set gave good results, we can supply it to the machine learning procedure that GaussPy employs to find the best smoothing parameters values $\alpha_{1}$ and $\alpha_{2}$. For this we execute the `train--grs.py` script contained in the `example` directory. See the `train--grs.py` script for more comments.
#
# **NOTE: Running this script will use 75% of all CPUs on the machine you are running it unless the** `use_ncpus` **parameter is specified.**
#
# Depending on the number of available CPUs the execution of this script might take a couple of minutes.

# %%
#  run the script
# !python train--grs.py
# Out:
# ================
# GaussPy training
# ================
# Using training set: decomposition_grs\gpy_training\grs-test_field-training_set_100_spectra.pickle
# Traceback (most recent call last):
#   File "train--grs.py", line 30, in <module>
#     train.training()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\training.py", line 73, in training
#     self.gausspy_train_alpha()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\training.py", line 83, in gausspy_train_alpha
#     g.load_training_data(self.path_to_training_set)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\gausspy_py3\gp.py", line 33, in load_training_data
#     self.p['training_data'] = pickle.load(open(filename, 'rb'), encoding='latin1')
# FileNotFoundError: [Errno 2] No such file or directory: 'decomposition_grs\\gpy_training\\grs-test_field-training_set_100_spectra.pickle'

# %% [markdown]
# ### Results
#
# In our case, we needed 47 iterations until a stable convergence was achieved. This yielded values for the smoothing parameters of $\alpha_{1} = 2.58$ and $\alpha_{2} = 5.14$.
#
# Note that the `decomposition_grs` directory now contains a new folder named `gpy_log`, which contains a log of the training results.

# %% [markdown]
# ## Step 3: Prepare the data for the decomposition
#
# Next, we have to prepare our data cube for the decomposition. Executing the script `prepare--grs.py` will automatically:
#
# - estimate the root-mean-square noise $\sigma_{\mathrm{rms}}$ of the spectra
#
# - determine regions in the spectra that are likely to contain signal peaks
#
# - mask out negative noise spikes (by default all data peaks with a minimum $< -5 \times \sigma_{\mathrm{rms}}$)
#
# - produce a pickled dictionary containing all necessary information for the decomposition
#
# **NOTE: Running this script will use 75% of all CPUs on the machine you are running it unless the** `use_ncpus` **parameter is specified.**

# %%
#  run the script
# !python prepare--grs.py
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#  41%|####1     | 412/1000 [00:00<00:00, 4090.11it/s]
#  83%|########2 | 826/1000 [00:00<00:00, 4096.04it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 4075.90it/s]
#
#   0%|          | 0.00/4.20k [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#  33%|###3      | 330/1000 [00:00<00:00, 3276.07it/s]
#  36%|###6      | 364/1000 [00:00<00:00, 3613.58it/s]
#  36%|###6      | 363/1000 [00:00<00:00, 3603.68it/s]
#  36%|###6      | 360/1000 [00:00<00:00, 3573.89it/s]
#  37%|###6      | 367/1000 [00:00<00:00, 3643.39it/s]
#  36%|###6      | 365/1000 [00:00<00:00, 3623.52it/s]
#  71%|#######1  | 713/1000 [00:00<00:00, 3399.80it/s]
#  74%|#######3  | 735/1000 [00:00<00:00, 3634.16it/s]
#  72%|#######2  | 725/1000 [00:00<00:00, 3600.69it/s]
#  72%|#######1  | 715/1000 [00:00<00:00, 3558.85it/s]
#  73%|#######2  | 726/1000 [00:00<00:00, 3619.20it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 3543.01it/s]
#  73%|#######3  | 732/1000 [00:00<00:00, 3629.45it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 3619.75it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 3593.81it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 3580.97it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 3530.53it/s]
# 100%|##########| 1000/1000 [00:00<00:00, 3593.81it/s]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 105, in spawn_main
#     exitcode = _main(fd)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 114, in _main
#     prepare(preparation_data)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 225, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 277, in _fixup_main_from_path
#     run_name="__mp_main__")
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 263, in run_path
#     pkg_name=pkg_name, script_name=fname)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 96, in _run_module_code
#     mod_name, mod_spec, pkg_name, script_name)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Tyler\Google Drive (barnanator@gmail.com)\College\2019-2020 Junior\343 Observational Astronomy\Project 2\Project Files\gausspyplus-master\example\prepare--grs.py", line 24, in <module>
#     prepare.prepare_cube()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 172, in prepare_cube
#     self.prepare_gausspy_pickle()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 210, in prepare_gausspy_pickle
#     results_list = gausspyplus.parallel_processing.func(use_ncpus=self.use_ncpus, function='gpy_noise')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 121, in func
#     results_list = parallel_process(mp_ilist, calculate_noise_gpy, n_jobs=use_ncpus)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in parallel_process
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in <listcomp>
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 641, in submit
#     self._start_queue_management_thread()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 583, in _start_queue_management_thread
#     self._adjust_process_count()
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
#
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
#
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
#
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
#
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
#
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
#
# calculating average rms from data...
# >> calculated rms value of 0.134 from data
#
# ===================
# GaussPy preparation
# ===================
#
# preparing GaussPy cube...
# Using 6 of 8 cpus
# SUCCESS
#
# 3 A process in the process pool was terminated abruptly while the future was running or pending.
# 4 A process in the process pool was terminated abruptly while the future was running or pending.
# 5 A process in the process pool was terminated abruptly while the future was running or pending.
# 6 A process in the process pool was terminated abruptly while the future was running or pending.
# 7 A process in the process pool was terminated abruptly while the future was running or pending.
# 8 A process in the process pool was terminated abruptly while the future was running or pending.
# 9 A process in the process pool was terminated abruptly while the future was running or pending.
# 10 A process in the process pool was terminated abruptly while the future was running or pending.
# 11 A process in the process pool was terminated abruptly while the future was running or pending.
# 12 A process in the process pool was terminated abruptly while the future was running or pending.
# 13 A process in the process pool was terminated abruptly while the future was running or pending.
# 14 A process in the process pool was terminated abruptly while the future was running or pending.
# 15 A process in the process pool was terminated abruptly while the future was running or pending.
# 16 A process in the process pool was terminated abruptly while the future was running or pending.
# 17 A process in the process pool was terminated abruptly while the future was running or pending.
# 18 A process in the process pool was terminated abruptly while the future was running or pending.
# 19 A process in the process pool was terminated abruptly while the future was running or pending.
# 20 A process in the process pool was terminated abruptly while the future was running or pending.
# 21 A process in the process pool was terminated abruptly while the future was running or pending.
# 22 A process in the process pool was terminated abruptly while the future was running or pending.
# 23 A process in the process pool was terminated abruptly while the future was running or pending.
# 24 A process in the process pool was terminated abruptly while the future was running or pending.
# 25 A process in the process pool was terminated abruptly while the future was running or pending.
# 26 A process in the process pool was terminated abruptly while the future was running or pending.
# 27 A process in the process pool was terminated abruptly while the future was running or pending.
# 28 A process in the process pool was terminated abruptly while the future was running or pending.
# 29 A process in the process pool was terminated abruptly while the future was running or pending.
# 30 A process in the process pool was terminated abruptly while the future was running or pending.
# 31 A process in the process pool was terminated abruptly while the future was running or pending.
# 32 A process in the process pool was terminated abruptly while the future was running or pending.
# 33 A process in the process pool was terminated abruptly while the future was running or pending.
# 34 A process in the process pool was terminated abruptly while the future was running or pending.
# 35 A process in the process pool was terminated abruptly while the future was running or pending.
# 36 A process in the process pool was terminated abruptly while the future was running or pending.
# 37 A process in the process pool was terminated abruptly while the future was running or pending.
# 38 A process in the process pool was terminated abruptly while the future was running or pending.
# 39 A process in the process pool was terminated abruptly while the future was running or pending.
# 40 A process in the process pool was terminated abruptly while the future was running or pending.
# 41 A process in the process pool was terminated abruptly while the future was running or pending.
# 42 A process in the process pool was terminated abruptly while the future was running or pending.
# 43 A process in the process pool was terminated abruptly while the future was running or pending.
# 44 A process in the process pool was terminated abruptly while the future was running or pending.
# 45 A process in the process pool was terminated abruptly while the future was running or pending.
# 46 A process in the process pool was terminated abruptly while the future was running or pending.
# 47 A process in the process pool was terminated abruptly while the future was running or pending.
# 48 A process in the process pool was terminated abruptly while the future was running or pending.
# 49 A process in the process pool was terminated abruptly while the future was running or pending.
# 50 A process in the process pool was terminated abruptly while the future was running or pending.
# 51 A process in the process pool was terminated abruptly while the future was running or pending.
# 52 A process in the process pool was terminated abruptly while the future was running or pending.
# 53 A process in the process pool was terminated abruptly while the future was running or pending.
# 54 A process in the process pool was terminated abruptly while the future was running or pending.
# 55 A process in the process pool was terminated abruptly while the future was running or pending.
# 56 A process in the process pool was terminated abruptly while the future was running or pending.
# 57 A process in the process pool was terminated abruptly while the future was running or pending.
# 58 A process in the process pool was terminated abruptly while the future was running or pending.
# 59 A process in the process pool was terminated abruptly while the future was running or pending.
# 60 A process in the process pool was terminated abruptly while the future was running or pending.
# 61 A process in the process pool was terminated abruptly while the future was running or pending.
# 62 A process in the process pool was terminated abruptly while the future was running or pending.
# 63 A process in the process pool was terminated abruptly while the future was running or pending.
# 64 A process in the process pool was terminated abruptly while the future was running or pending.
# 65 A process in the process pool was terminated abruptly while the future was running or pending.
# 66 A process in the process pool was terminated abruptly while the future was running or pending.
# 67 A process in the process pool was terminated abruptly while the future was running or pending.
# 68 A process in the process pool was terminated abruptly while the future was running or pending.
# 69 A process in the process pool was terminated abruptly while the future was running or pending.
# 70 A process in the process pool was terminated abruptly while the future was running or pending.
# 71 A process in the process pool was terminated abruptly while the future was running or pending.
# 72 A process in the process pool was terminated abruptly while the future was running or pending.
# 73 A process in the process pool was terminated abruptly while the future was running or pending.
# 74 A process in the process pool was terminated abruptly while the future was running or pending.
# 75 A process in the process pool was terminated abruptly while the future was running or pending.
# 76 A process in the process pool was terminated abruptly while the future was running or pending.
# 77 A process in the process pool was terminated abruptly while the future was running or pending.
# 78 A process in the process pool was terminated abruptly while the future was running or pending.
# 79 A process in the process pool was terminated abruptly while the future was running or pending.
# 80 A process in the process pool was terminated abruptly while the future was running or pending.
# 81 A process in the process pool was terminated abruptly while the future was running or pending.
# 82 A process in the process pool was terminated abruptly while the future was running or pending.
# 83 A process in the process pool was terminated abruptly while the future was running or pending.
# 84 A process in the process pool was terminated abruptly while the future was running or pending.
# 85 A process in the process pool was terminated abruptly while the future was running or pending.
# 86 A process in the process pool was terminated abruptly while the future was running or pending.
# 87 A process in the process pool was terminated abruptly while the future was running or pending.
# 88 A process in the process pool was terminated abruptly while the future was running or pending.
# 89 A process in the process pool was terminated abruptly while the future was running or pending.
# 90 A process in the process pool was terminated abruptly while the future was running or pending.
# 91 A process in the process pool was terminated abruptly while the future was running or pending.
# 92 A process in the process pool was terminated abruptly while the future was running or pending.
# 93 A process in the process pool was terminated abruptly while the future was running or pending.
# 94 A process in the process pool was terminated abruptly while the future was running or pending.
# 95 A process in the process pool was terminated abruptly while the future was running or pending.
# 96 A process in the process pool was terminated abruptly while the future was running or pending.
# 97 A process in the process pool was terminated abruptly while the future was running or pending.
# 98 A process in the process pool was terminated abruptly while the future was running or pending.
# 99 A process in the process pool was terminated abruptly while the future was running or pending.
# 100 A process in the process pool was terminated abruptly while the future was running or pending.
# 101 A process in the process pool was terminated abruptly while the future was running or pending.
# 102 A process in the process pool was terminated abruptly while the future was running or pending.
# 103 A process in the process pool was terminated abruptly while the future was running or pending.
# 104 A process in the process pool was terminated abruptly while the future was running or pending.
# 105 A process in the process pool was terminated abruptly while the future was running or pending.
# 106 A process in the process pool was terminated abruptly while the future was running or pending.
# 107 A process in the process pool was terminated abruptly while the future was running or pending.
# 108 A process in the process pool was terminated abruptly while the future was running or pending.
# 109 A process in the process pool was terminated abruptly while the future was running or pending.
# 110 A process in the process pool was terminated abruptly while the future was running or pending.
# 111 A process in the process pool was terminated abruptly while the future was running or pending.
# 112 A process in the process pool was terminated abruptly while the future was running or pending.
# 113 A process in the process pool was terminated abruptly while the future was running or pending.
# 114 A process in the process pool was terminated abruptly while the future was running or pending.
# 115 A process in the process pool was terminated abruptly while the future was running or pending.
# 116 A process in the process pool was terminated abruptly while the future was running or pending.
# 117 A process in the process pool was terminated abruptly while the future was running or pending.
# 118 A process in the process pool was terminated abruptly while the future was running or pending.
# 119 A process in the process pool was terminated abruptly while the future was running or pending.
# 120 A process in the process pool was terminated abruptly while the future was running or pending.
# 121 A process in the process pool was terminated abruptly while the future was running or pending.
# 122 A process in the process pool was terminated abruptly while the future was running or pending.
# 123 A process in the process pool was terminated abruptly while the future was running or pending.
# 124 A process in the process pool was terminated abruptly while the future was running or pending.
# 125 A process in the process pool was terminated abruptly while the future was running or pending.
# 126 A process in the process pool was terminated abruptly while the future was running or pending.
# 127 A process in the process pool was terminated abruptly while the future was running or pending.
# 128 A process in the process pool was terminated abruptly while the future was running or pending.
# 129 A process in the process pool was terminated abruptly while the future was running or pending.
# 130 A process in the process pool was terminated abruptly while the future was running or pending.
# 131 A process in the process pool was terminated abruptly while the future was running or pending.
# 132 A process in the process pool was terminated abruptly while the future was running or pending.
# 133 A process in the process pool was terminated abruptly while the future was running or pending.
# 134 A process in the process pool was terminated abruptly while the future was running or pending.
# 135 A process in the process pool was terminated abruptly while the future was running or pending.
# 136 A process in the process pool was terminated abruptly while the future was running or pending.
# 137 A process in the process pool was terminated abruptly while the future was running or pending.
# 138 A process in the process pool was terminated abruptly while the future was running or pending.
# 139 A process in the process pool was terminated abruptly while the future was running or pending.
# 140 A process in the process pool was terminated abruptly while the future was running or pending.
# 141 A process in the process pool was terminated abruptly while the future was running or pending.
# 142 A process in the process pool was terminated abruptly while the future was running or pending.
# 143 A process in the process pool was terminated abruptly while the future was running or pending.
# 144 A process in the process pool was terminated abruptly while the future was running or pending.
# 145 A process in the process pool was terminated abruptly while the future was running or pending.
# 146 A process in the process pool was terminated abruptly while the future was running or pending.
# 147 A process in the process pool was terminated abruptly while the future was running or pending.
# 148 A process in the process pool was terminated abruptly while the future was running or pending.
# 149 A process in the process pool was terminated abruptly while the future was running or pending.
# 150 A process in the process pool was terminated abruptly while the future was running or pending.
# 151 A process in the process pool was terminated abruptly while the future was running or pending.
# 152 A process in the process pool was terminated abruptly while the future was running or pending.
# 153 A process in the process pool was terminated abruptly while the future was running or pending.
# 154 A process in the process pool was terminated abruptly while the future was running or pending.
# 155 A process in the process pool was terminated abruptly while the future was running or pending.
# 156 A process in the process pool was terminated abruptly while the future was running or pending.
# 157 A process in the process pool was terminated abruptly while the future was running or pending.
# 158 A process in the process pool was terminated abruptly while the future was running or pending.
# 159 A process in the process pool was terminated abruptly while the future was running or pending.
# 160 A process in the process pool was terminated abruptly while the future was running or pending.
# 161 A process in the process pool was terminated abruptly while the future was running or pending.
# 162 A process in the process pool was terminated abruptly while the future was running or pending.
# 163 A process in the process pool was terminated abruptly while the future was running or pending.
# 164 A process in the process pool was terminated abruptly while the future was running or pending.
# 165 A process in the process pool was terminated abruptly while the future was running or pending.
# 166 A process in the process pool was terminated abruptly while the future was running or pending.
# 167 A process in the process pool was terminated abruptly while the future was running or pending.
# 168 A process in the process pool was terminated abruptly while the future was running or pending.
# 169 A process in the process pool was terminated abruptly while the future was running or pending.
# 170 A process in the process pool was terminated abruptly while the future was running or pending.
# 171 A process in the process pool was terminated abruptly while the future was running or pending.
# 172 A process in the process pool was terminated abruptly while the future was running or pending.
# 173 A process in the process pool was terminated abruptly while the future was running or pending.
# 174 A process in the process pool was terminated abruptly while the future was running or pending.
# 175 A process in the process pool was terminated abruptly while the future was running or pending.
# 176 A process in the process pool was terminated abruptly while the future was running or pending.
# 177 A process in the process pool was terminated abruptly while the future was running or pending.
# 178 A process in the process pool was terminated abruptly while the future was running or pending.
# 179 A process in the process pool was terminated abruptly while the future was running or pending.
# 180 A process in the process pool was terminated abruptly while the future was running or pending.
# 181 A process in the process pool was terminated abruptly while the future was running or pending.
# 182 A process in the process pool was terminated abruptly while the future was running or pending.
# 183 A process in the process pool was terminated abruptly while the future was running or pending.
# 184 A process in the process pool was terminated abruptly while the future was running or pending.
# 185 A process in the process pool was terminated abruptly while the future was running or pending.
# 186 A process in the process pool was terminated abruptly while the future was running or pending.
# 187 A process in the process pool was terminated abruptly while the future was running or pending.
# 188 A process in the process pool was terminated abruptly while the future was running or pending.
# 189 A process in the process pool was terminated abruptly while the future was running or pending.
# 190 A process in the process pool was terminated abruptly while the future was running or pending.
# 191 A process in the process pool was terminated abruptly while the future was running or pending.
# 192 A process in the process pool was terminated abruptly while the future was running or pending.
# 193 A process in the process pool was terminated abruptly while the future was running or pending.
# 194 A process in the process pool was terminated abruptly while the future was running or pending.
# 195 A process in the process pool was terminated abruptly while the future was running or pending.
# 196 A process in the process pool was terminated abruptly while the future was running or pending.
# 197 A process in the process pool was terminated abruptly while the future was running or pending.
# 198 A process in the process pool was terminated abruptly while the future was running or pending.
# 199 A process in the process pool was terminated abruptly while the future was running or pending.
# 200 A process in the process pool was terminated abruptly while the future was running or pending.
# 201 A process in the process pool was terminated abruptly while the future was running or pending.
# 202 A process in the process pool was terminated abruptly while the future was running or pending.
# 203 A process in the process pool was terminated abruptly while the future was running or pending.
# 204 A process in the process pool was terminated abruptly while the future was running or pending.
# 205 A process in the process pool was terminated abruptly while the future was running or pending.
# 206 A process in the process pool was terminated abruptly while the future was running or pending.
# 207 A process in the process pool was terminated abruptly while the future was running or pending.
# 208 A process in the process pool was terminated abruptly while the future was running or pending.
# 209 A process in the process pool was terminated abruptly while the future was running or pending.
# 210 A process in the process pool was terminated abruptly while the future was running or pending.
# 211 A process in the process pool was terminated abruptly while the future was running or pending.
# 212 A process in the process pool was terminated abruptly while the future was running or pending.
# 213 A process in the process pool was terminated abruptly while the future was running or pending.
# 214 A process in the process pool was terminated abruptly while the future was running or pending.
# 215 A process in the process pool was terminated abruptly while the future was running or pending.
# 216 A process in the process pool was terminated abruptly while the future was running or pending.
# 217 A process in the process pool was terminated abruptly while the future was running or pending.
# 218 A process in the process pool was terminated abruptly while the future was running or pending.
# 219 A process in the process pool was terminated abruptly while the future was running or pending.
# 220 A process in the process pool was terminated abruptly while the future was running or pending.
# 221 A process in the process pool was terminated abruptly while the future was running or pending.
# 222 A process in the process pool was terminated abruptly while the future was running or pending.
# 223 A process in the process pool was terminated abruptly while the future was running or pending.
# 224 A process in the process pool was terminated abruptly while the future was running or pending.
# 225 A process in the process pool was terminated abruptly while the future was running or pending.
# 226 A process in the process pool was terminated abruptly while the future was running or pending.
# 227 A process in the process pool was terminated abruptly while the future was running or pending.
# 228 A process in the process pool was terminated abruptly while the future was running or pending.
# 229 A process in the process pool was terminated abruptly while the future was running or pending.
# 230 A process in the process pool was terminated abruptly while the future was running or pending.
# 231 A process in the process pool was terminated abruptly while the future was running or pending.
# 232 A process in the process pool was terminated abruptly while the future was running or pending.
# 233 A process in the process pool was terminated abruptly while the future was running or pending.
# 234 A process in the process pool was terminated abruptly while the future was running or pending.
# 235 A process in the process pool was terminated abruptly while the future was running or pending.
# 236 A process in the process pool was terminated abruptly while the future was running or pending.
# 237 A process in the process pool was terminated abruptly while the future was running or pending.
# 238 A process in the process pool was terminated abruptly while the future was running or pending.
# 239 A process in the process pool was terminated abruptly while the future was running or pending.
# 240 A process in the process pool was terminated abruptly while the future was running or pending.
# 241 A process in the process pool was terminated abruptly while the future was running or pending.
# 242 A process in the process pool was terminated abruptly while the future was running or pending.
# 243 A process in the process pool was terminated abruptly while the future was running or pending.
# 244 A process in the process pool was terminated abruptly while the future was running or pending.
# 245 A process in the process pool was terminated abruptly while the future was running or pending.
# 246 A process in the process pool was terminated abruptly while the future was running or pending.
# 247 A process in the process pool was terminated abruptly while the future was running or pending.
# 248 A process in the process pool was terminated abruptly while the future was running or pending.
# 249 A process in the process pool was terminated abruptly while the future was running or pending.
# 250 A process in the process pool was terminated abruptly while the future was running or pending.
# 251 A process in the process pool was terminated abruptly while the future was running or pending.
# 252 A process in the process pool was terminated abruptly while the future was running or pending.
# 253 A process in the process pool was terminated abruptly while the future was running or pending.
# 254 A process in the process pool was terminated abruptly while the future was running or pending.
# 255 A process in the process pool was terminated abruptly while the future was running or pending.
# 256 A process in the process pool was terminated abruptly while the future was running or pending.
# 257 A process in the process pool was terminated abruptly while the future was running or pending.
# 258 A process in the process pool was terminated abruptly while the future was running or pending.
# 259 A process in the process pool was terminated abruptly while the future was running or pending.
# 260 A process in the process pool was terminated abruptly while the future was running or pending.
# 261 A process in the process pool was terminated abruptly while the future was running or pending.
# 262 A process in the process pool was terminated abruptly while the future was running or pending.
# 263 A process in the process pool was terminated abruptly while the future was running or pending.
# 264 A process in the process pool was terminated abruptly while the future was running or pending.
# 265 A process in the process pool was terminated abruptly while the future was running or pending.
# 266 A process in the process pool was terminated abruptly while the future was running or pending.
# 267 A process in the process pool was terminated abruptly while the future was running or pending.
# 268 A process in the process pool was terminated abruptly while the future was running or pending.
# 269 A process in the process pool was terminated abruptly while the future was running or pending.
# 270 A process in the process pool was terminated abruptly while the future was running or pending.
# 271 A process in the process pool was terminated abruptly while the future was running or pending.
# 272 A process in the process pool was terminated abruptly while the future was running or pending.
# 273 A process in the process pool was terminated abruptly while the future was running or pending.
# 274 A process in the process pool was terminated abruptly while the future was running or pending.
# 275 A process in the process pool was terminated abruptly while the future was running or pending.
# 276 A process in the process pool was terminated abruptly while the future was running or pending.
# 277 A process in the process pool was terminated abruptly while the future was running or pending.
# 278 A process in the process pool was terminated abruptly while the future was running or pending.
# 279 A process in the process pool was terminated abruptly while the future was running or pending.
# 280 A process in the process pool was terminated abruptly while the future was running or pending.
# 281 A process in the process pool was terminated abruptly while the future was running or pending.
# 282 A process in the process pool was terminated abruptly while the future was running or pending.
# 283 A process in the process pool was terminated abruptly while the future was running or pending.
# 284 A process in the process pool was terminated abruptly while the future was running or pending.
# 285 A process in the process pool was terminated abruptly while the future was running or pending.
# 286 A process in the process pool was terminated abruptly while the future was running or pending.
# 287 A process in the process pool was terminated abruptly while the future was running or pending.
# 288 A process in the process pool was terminated abruptly while the future was running or pending.
# 289 A process in the process pool was terminated abruptly while the future was running or pending.
# 290 A process in the process pool was terminated abruptly while the future was running or pending.
# 291 A process in the process pool was terminated abruptly while the future was running or pending.
# 292 A process in the process pool was terminated abruptly while the future was running or pending.
# 293 A process in the process pool was terminated abruptly while the future was running or pending.
# 294 A process in the process pool was terminated abruptly while the future was running or pending.
# 295 A process in the process pool was terminated abruptly while the future was running or pending.
# 296 A process in the process pool was terminated abruptly while the future was running or pending.
# 297 A process in the process pool was terminated abruptly while the future was running or pending.
# 298 A process in the process pool was terminated abruptly while the future was running or pending.
# 299 A process in the process pool was terminated abruptly while the future was running or pending.
# 300 A process in the process pool was terminated abruptly while the future was running or pending.
# 301 A process in the process pool was terminated abruptly while the future was running or pending.
# 302 A process in the process pool was terminated abruptly while the future was running or pending.
# 303 A process in the process pool was terminated abruptly while the future was running or pending.
# 304 A process in the process pool was terminated abruptly while the future was running or pending.
# 305 A process in the process pool was terminated abruptly while the future was running or pending.
# 306 A process in the process pool was terminated abruptly while the future was running or pending.
# 307 A process in the process pool was terminated abruptly while the future was running or pending.
# 308 A process in the process pool was terminated abruptly while the future was running or pending.
# 309 A process in the process pool was terminated abruptly while the future was running or pending.
# 310 A process in the process pool was terminated abruptly while the future was running or pending.
# 311 A process in the process pool was terminated abruptly while the future was running or pending.
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 607, in _adjust_process_count
#     p.start()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\popen_spawn_win32.py", line 46, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 143, in get_preparation_data
#     _check_not_importing_main()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 136, in _check_not_importing_main
#     is not going to be frozen to produce an executable.''')
# RuntimeError:
#         An attempt has been made to start a new process before the
#         current process has finished its bootstrapping phase.
#
#         This probably means that you are not using fork to start your
#         child processes and you have forgotten to use the proper idiom
#         in the main module:
#
#             if __name__ == '__main__':
#                 freeze_support()
#                 ...
#
#         The "freeze_support()" line can be omitted if the program
#         is not going to be frozen to produce an executable.
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 105, in spawn_main
#     exitcode = _main(fd)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 114, in _main
#     prepare(preparation_data)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 225, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 277, in _fixup_main_from_path
#     run_name="__mp_main__")
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 263, in run_path
#     pkg_name=pkg_name, script_name=fname)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 96, in _run_module_code
#     mod_name, mod_spec, pkg_name, script_name)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Tyler\Google Drive (barnanator@gmail.com)\College\2019-2020 Junior\343 Observational Astronomy\Project 2\Project Files\gausspyplus-master\example\prepare--grs.py", line 24, in <module>
#     prepare.prepare_cube()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 172, in prepare_cube
#     self.prepare_gausspy_pickle()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 210, in prepare_gausspy_pickle
#     results_list = gausspyplus.parallel_processing.func(use_ncpus=self.use_ncpus, function='gpy_noise')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 121, in func
#     results_list = parallel_process(mp_ilist, calculate_noise_gpy, n_jobs=use_ncpus)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in parallel_process
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in <listcomp>
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 641, in submit
#     self._start_queue_management_thread()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 583, in _start_queue_management_thread
#     self._adjust_process_count()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 607, in _adjust_process_count
#     p.start()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\popen_spawn_win32.py", line 46, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 143, in get_preparation_data
#     _check_not_importing_main()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 136, in _check_not_importing_main
#     is not going to be frozen to produce an executable.''')
# RuntimeError:
#         An attempt has been made to start a new process before the
#         current process has finished its bootstrapping phase.
#
#         This probably means that you are not using fork to start your
#         child processes and you have forgotten to use the proper idiom
#         in the main module:
#
#             if __name__ == '__main__':
#                 freeze_support()
#                 ...
#
#         The "freeze_support()" line can be omitted if the program
#         is not going to be frozen to produce an executable.
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 105, in spawn_main
#     exitcode = _main(fd)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 114, in _main
#     prepare(preparation_data)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 225, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 277, in _fixup_main_from_path
#     run_name="__mp_main__")
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 263, in run_path
#     pkg_name=pkg_name, script_name=fname)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 96, in _run_module_code
#     mod_name, mod_spec, pkg_name, script_name)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Tyler\Google Drive (barnanator@gmail.com)\College\2019-2020 Junior\343 Observational Astronomy\Project 2\Project Files\gausspyplus-master\example\prepare--grs.py", line 24, in <module>
#     prepare.prepare_cube()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 172, in prepare_cube
#     self.prepare_gausspy_pickle()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 210, in prepare_gausspy_pickle
#     results_list = gausspyplus.parallel_processing.func(use_ncpus=self.use_ncpus, function='gpy_noise')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 121, in func
#     results_list = parallel_process(mp_ilist, calculate_noise_gpy, n_jobs=use_ncpus)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in parallel_process
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in <listcomp>
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 641, in submit
#     self._start_queue_management_thread()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 583, in _start_queue_management_thread
#     self._adjust_process_count()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 607, in _adjust_process_count
#     p.start()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\popen_spawn_win32.py", line 46, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 143, in get_preparation_data
#     _check_not_importing_main()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 136, in _check_not_importing_main
#     is not going to be frozen to produce an executable.''')
# RuntimeError:
#         An attempt has been made to start a new process before the
#         current process has finished its bootstrapping phase.
#
#         This probably means that you are not using fork to start your
#         child processes and you have forgotten to use the proper idiom
#         in the main module:
#
#             if __name__ == '__main__':
#                 freeze_support()
#                 ...
#
#         The "freeze_support()" line can be omitted if the program
#         is not going to be frozen to produce an executable.
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 105, in spawn_main
#     exitcode = _main(fd)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 114, in _main
#     prepare(preparation_data)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 225, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 277, in _fixup_main_from_path
#     run_name="__mp_main__")
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 263, in run_path
#     pkg_name=pkg_name, script_name=fname)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 96, in _run_module_code
#     mod_name, mod_spec, pkg_name, script_name)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Tyler\Google Drive (barnanator@gmail.com)\College\2019-2020 Junior\343 Observational Astronomy\Project 2\Project Files\gausspyplus-master\example\prepare--grs.py", line 24, in <module>
#     prepare.prepare_cube()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 172, in prepare_cube
#     self.prepare_gausspy_pickle()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\prepare.py", line 210, in prepare_gausspy_pickle
#     results_list = gausspyplus.parallel_processing.func(use_ncpus=self.use_ncpus, function='gpy_noise')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 121, in func
#     results_list = parallel_process(mp_ilist, calculate_noise_gpy, n_jobs=use_ncpus)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in parallel_process
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\gausspyplus-0.0.dev0-py3.7.egg\gausspyplus\parallel_processing.py", line 90, in <listcomp>
#     futures = [pool.submit(function, a) for a in array[front_num:]]
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 641, in submit
#     self._start_queue_management_thread()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 583, in _start_queue_management_thread
#     self._adjust_process_count()
#   File "C:\ProgramData\Anaconda3\lib\concurrent\futures\process.py", line 607, in _adjust_process_count
#     p.start()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\context.py", line 322, in _Popen
#     return Popen(process_obj)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\popen_spawn_win32.py", line 46, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 143, in get_preparation_data
#     _check_not_importing_main()
#   File "C:\ProgramData\Anaconda3\lib\multiprocessing\spawn.py", line 136, in _check_not_importing_main
#     is not going to be frozen to produce an executable.''')
# RuntimeError:
# ...
# 4043 A process in the process pool was terminated abruptly while the future was running or pending.
# 4044 A process in the process pool was terminated abruptly while the future was running or pending.
# 4045 A process in the process pool was terminated abruptly while the future was running or pending.
# 4046 A process in the process pool was terminated abruptly while the future was running or pending.
# 4047 A process in the process pool was terminated abruptly while the future was running or pending.
# 4048 A process in the process pool was terminated abruptly while the future was running or pending.
# 4049 A process in the process pool was terminated abruptly while the future was running or pending.
# 4050 A process in the process pool was terminated abruptly while the future was running or pending.
# 4051 A process in the process pool was terminated abruptly while the future was running or pending.
# 4052 A process in the process pool was terminated abruptly while the future was running or pending.
# 4053 A process in the process pool was terminated abruptly while the future was running or pending.
# 4054 A process in the process pool was terminated abruptly while the future was running or pending.
# 4055 A process in the process pool was terminated abruptly while the future was running or pending.
# 4056 A process in the process pool was terminated abruptly while the future was running or pending.
# 4057 A process in the process pool was terminated abruptly while the future was running or pending.
# 4058 A process in the process pool was terminated abruptly while the future was running or pending.
# 4059 A process in the process pool was terminated abruptly while the future was running or pending.
# 4060 A process in the process pool was terminated abruptly while the future was running or pending.
# 4061 A process in the process pool was terminated abruptly while the future was running or pending.
# 4062 A process in the process pool was terminated abruptly while the future was running or pending.
# 4063 A process in the process pool was terminated abruptly while the future was running or pending.
# 4064 A process in the process pool was terminated abruptly while the future was running or pending.
# 4065 A process in the process pool was terminated abruptly while the future was running or pending.
# 4066 A process in the process pool was terminated abruptly while the future was running or pending.
# 4067 A process in the process pool was terminated abruptly while the future was running or pending.
# 4068 A process in the process pool was terminated abruptly while the future was running or pending.
# 4069 A process in the process pool was terminated abruptly while the future was running or pending.
# 4070 A process in the process pool was terminated abruptly while the future was running or pending.
# 4071 A process in the process pool was terminated abruptly while the future was running or pending.
# 4072 A process in the process pool was terminated abruptly while the future was running or pending.
# 4073 A process in the process pool was terminated abruptly while the future was running or pending.
# 4074 A process in the process pool was terminated abruptly while the future was running or pending.
# 4075 A process in the process pool was terminated abruptly while the future was running or pending.
# 4076 A process in the process pool was terminated abruptly while the future was running or pending.
# 4077 A process in the process pool was terminated abruptly while the future was running or pending.
# 4078 A process in the process pool was terminated abruptly while the future was running or pending.
# 4079 A process in the process pool was terminated abruptly while the future was running or pending.
# 4080 A process in the process pool was terminated abruptly while the future was running or pending.
# 4081 A process in the process pool was terminated abruptly while the future was running or pending.
# 4082 A process in the process pool was terminated abruptly while the future was running or pending.
# 4083 A process in the process pool was terminated abruptly while the future was running or pending.
# 4084 A process in the process pool was terminated abruptly while the future was running or pending.
# 4085 A process in the process pool was terminated abruptly while the future was running or pending.
# 4086 A process in the process pool was terminated abruptly while the future was running or pending.
# 4087 A process in the process pool was terminated abruptly while the future was running or pending.
# 4088 A process in the process pool was terminated abruptly while the future was running or pending.
# 4089 A process in the process pool was terminated abruptly while the future was running or pending.
# 4090 A process in the process pool was terminated abruptly while the future was running or pending.
# 4091 A process in the process pool was terminated abruptly while the future was running or pending.
# 4092 A process in the process pool was terminated abruptly while the future was running or pending.
# 4093 A process in the process pool was terminated abruptly while the future was running or pending.
# 4094 A process in the process pool was terminated abruptly while the future was running or pending.
# 4095 A process in the process pool was terminated abruptly while the future was running or pending.
# 4096 A process in the process pool was terminated abruptly while the future was running or pending.
# 4097 A process in the process pool was terminated abruptly while the future was running or pending.
# 4098 A process in the process pool was terminated abruptly while the future was running or pending.
# 4099 A process in the process pool was terminated abruptly while the future was running or pending.
# 4100 A process in the process pool was terminated abruptly while the future was running or pending.
# 4101 A process in the process pool was terminated abruptly while the future was running or pending.
# 4102 A process in the process pool was terminated abruptly while the future was running or pending.
# 4103 A process in the process pool was terminated abruptly while the future was running or pending.
# 4104 A process in the process pool was terminated abruptly while the future was running or pending.
# 4105 A process in the process pool was terminated abruptly while the future was running or pending.
# 4106 A process in the process pool was terminated abruptly while the future was running or pending.
# 4107 A process in the process pool was terminated abruptly while the future was running or pending.
# 4108 A process in the process pool was terminated abruptly while the future was running or pending.
# 4109 A process in the process pool was terminated abruptly while the future was running or pending.
# 4110 A process in the process pool was terminated abruptly while the future was running or pending.
# 4111 A process in the process pool was terminated abruptly while the future was running or pending.
# 4112 A process in the process pool was terminated abruptly while the future was running or pending.
# 4113 A process in the process pool was terminated abruptly while the future was running or pending.
# 4114 A process in the process pool was terminated abruptly while the future was running or pending.
# 4115 A process in the process pool was terminated abruptly while the future was running or pending.
# 4116 A process in the process pool was terminated abruptly while the future was running or pending.
# 4117 A process in the process pool was terminated abruptly while the future was running or pending.
# 4118 A process in the process pool was terminated abruptly while the future was running or pending.
# 4119 A process in the process pool was terminated abruptly while the future was running or pending.
# 4120 A process in the process pool was terminated abruptly while the future was running or pending.
# 4121 A process in the process pool was terminated abruptly while the future was running or pending.
# 4122 A process in the process pool was terminated abruptly while the future was running or pending.
# 4123 A process in the process pool was terminated abruptly while the future was running or pending.
# 4124 A process in the process pool was terminated abruptly while the future was running or pending.
# 4125 A process in the process pool was terminated abruptly while the future was running or pending.
# 4126 A process in the process pool was terminated abruptly while the future was running or pending.
# 4127 A process in the process pool was terminated abruptly while the future was running or pending.
# 4128 A process in the process pool was terminated abruptly while the future was running or pending.
# 4129 A process in the process pool was terminated abruptly while the future was running or pending.
# 4130 A process in the process pool was terminated abruptly while the future was running or pending.
# 4131 A process in the process pool was terminated abruptly while the future was running or pending.
# 4132 A process in the process pool was terminated abruptly while the future was running or pending.
# 4133 A process in the process pool was terminated abruptly while the future was running or pending.
# 4134 A process in the process pool was terminated abruptly while the future was running or pending.
# 4135 A process in the process pool was terminated abruptly while the future was running or pending.
# 4136 A process in the process pool was terminated abruptly while the future was running or pending.
# 4137 A process in the process pool was terminated abruptly while the future was running or pending.
# 4138 A process in the process pool was terminated abruptly while the future was running or pending.
# 4139 A process in the process pool was terminated abruptly while the future was running or pending.
# 4140 A process in the process pool was terminated abruptly while the future was running or pending.
# 4141 A process in the process pool was terminated abruptly while the future was running or pending.
# 4142 A process in the process pool was terminated abruptly while the future was running or pending.
# 4143 A process in the process pool was terminated abruptly while the future was running or pending.
# 4144 A process in the process pool was terminated abruptly while the future was running or pending.
# 4145 A process in the process pool was terminated abruptly while the future was running or pending.
# 4146 A process in the process pool was terminated abruptly while the future was running or pending.
# 4147 A process in the process pool was terminated abruptly while the future was running or pending.
# 4148 A process in the process pool was terminated abruptly while the future was running or pending.
# 4149 A process in the process pool was terminated abruptly while the future was running or pending.
# 4150 A process in the process pool was terminated abruptly while the future was running or pending.
# 4151 A process in the process pool was terminated abruptly while the future was running or pending.
# 4152 A process in the process pool was terminated abruptly while the future was running or pending.
# 4153 A process in the process pool was terminated abruptly while the future was running or pending.
# 4154 A process in the process pool was terminated abruptly while the future was running or pending.
# 4155 A process in the process pool was terminated abruptly while the future was running or pending.
# 4156 A process in the process pool was terminated abruptly while the future was running or pending.
# 4157 A process in the process pool was terminated abruptly while the future was running or pending.
# 4158 A process in the process pool was terminated abruptly while the future was running or pending.
# 4159 A process in the process pool was terminated abruptly while the future was running or pending.
# 4160 A process in the process pool was terminated abruptly while the future was running or pending.
# 4161 A process in the process pool was terminated abruptly while the future was running or pending.
# 4162 A process in the process pool was terminated abruptly while the future was running or pending.
# 4163 A process in the process pool was terminated abruptly while the future was running or pending.
# 4164 A process in the process pool was terminated abruptly while the future was running or pending.
# 4165 A process in the process pool was terminated abruptly while the future was running or pending.
# 4166 A process in the process pool was terminated abruptly while the future was running or pending.
# 4167 A process in the process pool was terminated abruptly while the future was running or pending.
# 4168 A process in the process pool was terminated abruptly while the future was running or pending.
# 4169 A process in the process pool was terminated abruptly while the future was running or pending.
# 4170 A process in the process pool was terminated abruptly while the future was running or pending.
# 4171 A process in the process pool was terminated abruptly while the future was running or pending.
# 4172 A process in the process pool was terminated abruptly while the future was running or pending.
# 4173 A process in the process pool was terminated abruptly while the future was running or pending.
# 4174 A process in the process pool was terminated abruptly while the future was running or pending.
# 4175 A process in the process pool was terminated abruptly while the future was running or pending.
# 4176 A process in the process pool was terminated abruptly while the future was running or pending.
# 4177 A process in the process pool was terminated abruptly while the future was running or pending.
# 4178 A process in the process pool was terminated abruptly while the future was running or pending.
# 4179 A process in the process pool was terminated abruptly while the future was running or pending.
# 4180 A process in the process pool was terminated abruptly while the future was running or pending.
# 4181 A process in the process pool was terminated abruptly while the future was running or pending.
# 4182 A process in the process pool was terminated abruptly while the future was running or pending.
# 4183 A process in the process pool was terminated abruptly while the future was running or pending.
# 4184 A process in the process pool was terminated abruptly while the future was running or pending.
# 4185 A process in the process pool was terminated abruptly while the future was running or pending.
# 4186 A process in the process pool was terminated abruptly while the future was running or pending.
# 4187 A process in the process pool was terminated abruptly while the future was running or pending.
# 4188 A process in the process pool was terminated abruptly while the future was running or pending.
# 4189 A process in the process pool was terminated abruptly while the future was running or pending.
# 4190 A process in the process pool was terminated abruptly while the future was running or pending.
# 4191 A process in the process pool was terminated abruptly while the future was running or pending.
# 4192 A process in the process pool was terminated abruptly while the future was running or pending.
# 4193 A process in the process pool was terminated abruptly while the future was running or pending.
# 4194 A process in the process pool was terminated abruptly while the future was running or pending.
# 4195 A process in the process pool was terminated abruptly while the future was running or pending.
# 4196 A process in the process pool was terminated abruptly while the future was running or pending.
# 4197 A process in the process pool was terminated abruptly while the future was running or pending.
# 4198 A process in the process pool was terminated abruptly while the future was running or pending.
# 4199 A process in the process pool was terminated abruptly while the future was running or pending.
#
# pickle dump dictionary...
# For GaussPyDecompose: 'path_to_pickle_file' = 'decomposition_grs\gpy_prepared\grs-test_field.pickle'
#
# SAVED FILE: 'grs-test_field_noise_map.fits' in 'decomposition_grs\gpy_maps'
#
# Plotting...

# %% [markdown]
# ### Results
# After this script was successfully executed, the `decomposition_grs` directory should contain a folder named `gpy_prepared` that contains `grs-test_field.pickle`, which is a pickled dictionary of the prepared data cube.
#
# The `decomposition_grs` directory should also contain a new folder named `gpy_maps` that contains the file `grs-test_field_noise_map.fits`, which is a map of the estimated rms noise values of our GRS test field.
#
# Lets take a look at the noise map:

# %%
filepath = os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_noise_map.fits')
noise = fits.getdata(filepath)
wcs = WCS(fits.getheader(filepath))

fig, ax = plt.subplots(figsize=(6, 4), subplot_kw=dict(projection=wcs))

img_noise = ax.imshow(noise, cmap='plasma_r', vmin=0.075, vmax=0.375)
fig.colorbar(img_noise, ax=ax, extend='max')
ax.set_title('Noise map')
add_style(ax)

plt.show()

# %% [markdown]
# The `prepare--grs.py` script also plotted all spectra within pixel ranges $30 \leq \text{X} \leq 34$ and $25 \leq \text{Y} \leq 29$ and saved it as `grs-test_field_plots.pdf` in the `gpy_plots` directory.
#
# The spectra are plotted in the correct spatial order to aid in comparing differences between neighboring spectra. The shaded red areas indicate the regions of the spectrum that were identified to contain signal (goodness of fit calculations are restricted to these areas). The dotted horizontal red lines indicate the estimated noise values of $\pm \sigma_{\mathrm{rms}}$ and the horizontal dashed line marks a S/N ratio of 3. The title of each subplot contains information about the location in terms of pixels and the index of the spectrum in the `grs-test_field.pickle` dictionary.

# %% [markdown]
# ## Step 4: Decomposition of the data
#
# After the successful preparation of the data, we can proceed to the decomposition of the data.
#
# The following script will run an improved fitting routine on top of the original GaussPy decomposition routine; for more details see Sect. 3.2. in Riener+ 2019.
#
# **NOTE: Running this script will use 75% of all CPUs on the machine you are running it unless the** `use_ncpus` **parameter is specified.**
#
# Depending on the number of available CPUs the execution of this script might take a couple of minutes.

# %%
#  run the script
# !python decompose--grs.py

# %% [markdown]
# ### Results
# After this script was successfully executed, the `decomposition_grs` directory should contain a folder named `gpy_decomposed` that contains `grs-test_field_g+_fit_fin.pickle`, which is a pickled dictionary of the decomposition results.
#
# In addition, we also produced a map showing the number of fitted components and a map showing the $\chi_{\mathrm{red}}^{2}$ values of the fit.
#
# Lets take a look at both of these maps:

# %%
filepath = os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_g+_rchi2_map.fits')
rchi2 = fits.getdata(filepath)
wcs = WCS(fits.getheader(filepath))

fig, axes = plt.subplots(ncols=2, figsize=(12, 4), subplot_kw=dict(projection=wcs))

ax = axes.flatten()[0]

vmin = min(rchi2.flatten())
vmax = 2.5
new_cmap = get_cmap_rchi2(vmin, vmax)

img_rchi2 = ax.imshow(rchi2, cmap=new_cmap, vmin=vmin, vmax=vmax)
fig.colorbar(img_rchi2, ax=ax, extend='max')
ax.set_title('$\chi_{\mathrm{red}}^{2}$ map')
add_style(ax)

ax = axes.flatten()[1]

ncomps = fits.getdata(os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_g+_component_map.fits'))

vmax = 6
new_cmap = cm.get_cmap('Spectral_r', vmax + 1)

img_ncomps = ax.imshow(ncomps, cmap=new_cmap, vmin=0, vmax=vmax)
fig.colorbar(img_ncomps, ax=ax)
ax.set_title('Number of fitted components')
add_style(ax)

fig.suptitle('After first decomposition with improved fitting routine')

plt.show()

# %% [markdown]
# ## Step 5: Spatially coherent refitting - phase 1
#
# Next we will try to improve upon the decomposition results obtained in the last step. For this, we try to refit spectra that were flagged as not satisfying our chosen quality criteria. For more details see Sect.$\,$3.3.1. in Riener+ 2019 for more details.
#
# For this we execute the `spatial_refitting-p1--grs.py` script contained in the `example` directory. See the `spatial_refitting-p1--grs.py` script for more comments.
#
# **NOTE: Running this script will use 75% of all CPUs on the machine you are running it unless the** `use_ncpus` **parameter is specified.**
#
# Depending on the number of available CPUs the execution of this script might take a couple of minutes.

# %%
#  run the script
# !python spatial_refitting-p1--grs.py

# %% [markdown]
# ### Results
# After this script was successfully executed, the `gpy_decomposed` folder contains the new file `grs-test_field_g+_fit_fin_sf-p1.pickle`, which is a pickled dictionary of the new decomposition results.
#
# In addition, we also produced new corresponding mapa of the number of fitted components and $\chi_{\mathrm{red}}^{2}$ values of the fit.
#
# Lets take a look again at both of these maps:

# %%
filepath = os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_g+_fit_fin_sf-p1_rchi2_map.fits')
rchi2 = fits.getdata(filepath)
header = fits.getheader(filepath)
wcs = WCS(header)

fig, axes = plt.subplots(ncols=2, figsize=(12, 4), subplot_kw=dict(projection=wcs))

ax = axes.flatten()[0]

vmin = min(rchi2.flatten())
vmax = 2.5
new_cmap = get_cmap_rchi2(vmin, vmax)

img_rchi2 = ax.imshow(rchi2, cmap=new_cmap, vmin=vmin, vmax=vmax)
fig.colorbar(img_rchi2, ax=ax, extend='max')
ax.set_title('$\chi_{\mathrm{red}}^{2}$ map')
add_style(ax)

ax = axes.flatten()[1]

ncomps = fits.getdata(
    os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_g+_fit_fin_sf-p1_component_map.fits'))

vmax = 6
new_cmap = cm.get_cmap('Spectral_r', vmax + 1)

img_ncomps = ax.imshow(ncomps, cmap=new_cmap, vmin=0, vmax=vmax)
fig.colorbar(img_ncomps, ax=ax)
ax.set_title('Number of fitted components')
add_style(ax)

fig.suptitle('After spatially coherent refitting - phase 1')

plt.show()

# %% [markdown]
# We can see that the $\chi_{\mathrm{red}}^{2}$ values of the fit did not change significantly; however the map of the number of fitted components shows already more spatial coherence. We can also check the new fit results for our 25 neighboring spectra that are plotted in `grs-test_field_g+_fit_fin_sf-p1_plots.pdf`. These plots also confirm that we gained a significant improvement in terms of spatial coherence of the fit results.

# %% [markdown]
# ## Step 6: Spatially coherent refitting - phase 2
#
# In the last step, we try to further improve upon the decomposition results obtained in the last step by checking the coherence of the centroid positions of the fitted Gaussian components. See Sect.$\,$3.3.2. in Riener+ 2019 for more details.
#
# For this we execute the `spatial_refitting-p2--grs.py` script contained in the `example` directory. See the `spatial_refitting-p2--grs.py` script for more comments.
#
# **NOTE: Running this script will use 75% of all CPUs on the machine you are running it unless the** `use_ncpus` **parameter is specified.**
#
# Depending on the number of available CPUs the execution of this script might take a couple of minutes.

# %%
#  run the script
# !python spatial_refitting-p2--grs.py

# %% [markdown]
# ### Results
# After this script was successfully executed, the `gpy_decomposed` folder contains the new file `grs-test_field_g+_fit_fin_sf-p2.pickle`, which is a pickled dictionary of the new decomposition results.
#
# In addition, we also produced new corresponding maps of the number of fitted components and $\chi_{\mathrm{red}}^{2}$ values of the fit.
#
# Lets take a look again at both of these maps:

# %%
filepath = os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_g+_fit_fin_sf-p2_rchi2_map.fits')
rchi2 = fits.getdata(filepath)
wcs = WCS(fits.getheader(filepath))

fig, axes = plt.subplots(ncols=2, figsize=(12, 4), subplot_kw=dict(projection=wcs))

ax = axes.flatten()[0]

vmin = min(rchi2.flatten())
vmax = 2.5
new_cmap = get_cmap_rchi2(vmin, vmax)

img_rchi2 = ax.imshow(rchi2, cmap=new_cmap, vmin=vmin, vmax=vmax)
fig.colorbar(img_rchi2, ax=ax, extend='max')
ax.set_title('$\chi_{\mathrm{red}}^{2}$ map')
add_style(ax)

ax = axes.flatten()[1]

ncomps = fits.getdata(
    os.path.join('decomposition_grs', 'gpy_maps', 'grs-test_field_g+_fit_fin_sf-p2_component_map.fits'))

vmax = 6
new_cmap = cm.get_cmap('Spectral_r', vmax + 1)

img_ncomps = ax.imshow(ncomps, cmap=new_cmap, vmin=0, vmax=vmax)
fig.colorbar(img_ncomps, ax=ax)
ax.set_title('Number of fitted components')
add_style(ax)

fig.suptitle('After spatially coherent refitting - phase 2')

plt.show()

# %% [markdown]
# Judging by the map showing the number of fitted components we seem to have gained a more spatial coherence. The new and final fit results for our 25 neighboring spectra are plotted in `grs-test_field_g+_fit_fin_sf-p2_plots.pdf`.

# %% [markdown]
# ### Note
# We could have combined the preparation and decomposition steps in a single script, but for illustrative purposes we have executed them seperately in this tutorial.
